# %%
# Import libraries

import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) # Adjusts the configuration of the plots we will create

# Read in the data

df = pd.read_csv(r'/Users/ThomasSmelter/Downloads/movies.csv')

# %%
# Open and view the new data frame

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# Find any missing data

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col,pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
# Data types for columns

df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
df['budget'] = df['budget'].dropna().astype('int64')
df['gross'] = df['gross'].dropna().astype('int64')

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
# reconcile the two year columns by creating new year column

# df['released'] = (
#     df['released']
#     .fillna('')                    # Handle NaNs up front
#     .astype(str)                  # Make sure everything is a string
#     .str.split(',')               # Split by comma
#     .str.get(1)                   # Take the second item
#     .fillna('')                   # Handle rows with no comma (i.e., get(1) returns NaN)
#     .str.strip()                  # Remove extra spaces
#     .str[:4]                      # Take first 4 characters (the year)
# )

df = pd.read_csv(r'/Users/ThomasSmelter/Downloads/movies.csv')

df['released'].head(10)
# Out:
# 0        June 13, 1980 (United States)
# 1         July 2, 1980 (United States)
# 2        June 20, 1980 (United States)
# 3         July 2, 1980 (United States)
# 4        July 25, 1980 (United States)
# 5          May 9, 1980 (United States)
# 6        June 20, 1980 (United States)
# 7    December 19, 1980 (United States)
# 8        June 19, 1981 (United States)
# 9         May 16, 1980 (United States)
# Name: released, dtype: object

# %%
def extract_year_after_comma(val):
    try:
        parts = str(val).split(',')
        if len(parts) > 1:
            return parts[1].strip()[:4]
        else:
            return ''
    except:
        return ''

df['released'] = df['released'].apply(extract_year_after_comma)

# %%
df['released'].head(10)
# Out:
# 0    1980
# 1    1980
# 2    1980
# 3    1980
# 4    1980
# 5    1980
# 6    1980
# 7    1980
# 8    1981
# 9    1980
# Name: released, dtype: object

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
df.sort_values(by=['gross'],inplace=False,ascending=False)
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
# ...                                          ...    ...     ...   ...
# 7663                                More to Life    NaN   Drama  2020
# 7664                                 Dream Round    NaN  Comedy  2020
# 7665                               Saving Mbango    NaN   Drama  2020
# 7666                                It's Just Us    NaN   Drama  2020
# 7667                                   Tee em el    NaN  Horror  2020
#
#      released  score      votes       director              writer  \
# ...

# %%
# make the output show all the rows
pd.set_option('display.max_rows', None)

# %%
# check to see if there are any duplicates and drop
df['company'].drop_duplicates().sort_values(ascending=False)
df.head()
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   533       5      0  2009        30    7.8  1100000.0      1155    1778
# 7445   535       5      0  2019        40    8.4   903000.0       162     743
# 3045  6896       5      6  1997        18    7.8  1100000.0      1155    1778
# 6663  5144       5      0  2015        36    7.8   876000.0      1125    2550
# 7244   536       5      0  2018        39    8.4   897000.0       162     743
#
#       star  country       budget         gross  company  runtime
# 5445  2334       55  237000000.0  2.847246e+09     2253    162.0
# 7445  2241       55  356000000.0  2.797501e+09     1606    181.0
# 3045  1595       55  200000000.0  2.201647e+09     2253    194.0
# 6663   524       55  245000000.0  2.069522e+09     1540    138.0
# 7244  2241       55  321000000.0  2.048360e+09     1606    149.0

# %%
# Check to see whether 'Budget' and 'Company' lead to high correlations in gross revenue 

# Build a scatterplot with budget vs gross
plt.scatter(x=df['budget'],y=df['gross'])

plt.title('Budget vs Gross Earnings')

plt.xlabel('Gross Earnings')

plt.ylabel('Budget for Film')

plt.show()

# %%
df = df.sort_values(by=['gross'],inplace=False,ascending=False)

# %%
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#      released  score      votes       director              writer  \
# 5445     2009    7.8  1100000.0  James Cameron       James Cameron
# 7445     2019    8.4   903000.0  Anthony Russo  Christopher Markus
# 3045     1997    7.8  1100000.0  James Cameron       James Cameron
# 6663     2015    7.8   876000.0    J.J. Abrams     Lawrence Kasdan
# 7244     2018    8.4   897000.0  Anthony Russo  Christopher Markus
#
#                    star        country       budget         gross  \
# 5445    Sam Worthington  United States  237000000.0  2.847246e+09
# ...

# %%
# in the above chart, it appears that the two variables are related.
# so let's add a regression line
# Plot budget vs gross using seaborn

sns.regplot(x='budget',y='gross',data=df, scatter_kws={"color": "red"},line_kws={"color":"blue"})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
# In order to explore this relationship further, let's run a correlation test

numeric_df = df.select_dtypes(include=['number'])

correlation_matrix = numeric_df.corr(method='pearson')
print(correlation_matrix)
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.329321  0.257486  0.120811
# score    0.097995  1.000000  0.409182  0.076254  0.186258  0.399451
# votes    0.222945  0.409182  1.000000  0.442429  0.630757  0.309212
# budget   0.329321  0.076254  0.442429  1.000000  0.740395  0.320447
# gross    0.257486  0.186258  0.630757  0.740395  1.000000  0.245216
# runtime  0.120811  0.399451  0.309212  0.320447  0.245216  1.000000

# %%
# we can see here that there is a high correlation between budget and gross revenue
# now let's create a heat map for the correlation matrix

sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matrix for Numeric Features')

plt.xlabel('Movie Features')

plt.ylabel('Movie Features')

plt.show()

# %%
# See if company is correlated with gross revenue
# first we will need to create a column with a number corresponding to each film production company

df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#      released  score      votes       director              writer  \
# 5445     2009    7.8  1100000.0  James Cameron       James Cameron
# 7445     2019    8.4   903000.0  Anthony Russo  Christopher Markus
# 3045     1997    7.8  1100000.0  James Cameron       James Cameron
# 6663     2015    7.8   876000.0    J.J. Abrams     Lawrence Kasdan
# 7244     2018    8.4   897000.0  Anthony Russo  Christopher Markus
#
#                    star        country       budget         gross  \
# 5445    Sam Worthington  United States  237000000.0  2.847246e+09
# ...

# %%
# See if company is correlated with gross revenue
# first we will need to create a column with a number corresponding to each film production company

df_numerized = df

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes

df_numerized.head()
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   533       5      0  2009        30    7.8  1100000.0      1155    1778
# 7445   535       5      0  2019        40    8.4   903000.0       162     743
# 3045  6896       5      6  1997        18    7.8  1100000.0      1155    1778
# 6663  5144       5      0  2015        36    7.8   876000.0      1125    2550
# 7244   536       5      0  2018        39    8.4   897000.0       162     743
#
#       star  country       budget         gross  company  runtime
# 5445  2334       55  237000000.0  2.847246e+09     2253    162.0
# 7445  2241       55  356000000.0  2.797501e+09     1606    181.0
# 3045  1595       55  200000000.0  2.201647e+09     2253    194.0
# 6663   524       55  245000000.0  2.069522e+09     1540    138.0
# 7244  2241       55  321000000.0  2.048360e+09     1606    149.0

# %%
correlation_matrix = df_numerized.corr(method='pearson')

sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matrix for Numeric Features')

plt.xlabel('Movie Features')

plt.ylabel('Movie Features')

plt.show()

# %%
correlation_mat = df_numerized.corr()

# %%
# organize the above table to see the largest correlations

corr_pairs = correlation_mat.unstack()

corr_pairs.head(10)
# Out:
# name  name        1.000000
#       rating     -0.008069
#       genre       0.016355
#       year        0.011453
#       released    0.009553
#       score       0.017097
#       votes       0.013088
#       director    0.009079
#       writer      0.009081
#       star        0.006472
# dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()

sorted_pairs.head(10)
# Out:
# genre    budget    -0.356564
# budget   genre     -0.356564
# genre    gross     -0.235650
# gross    genre     -0.235650
# budget   rating    -0.176002
# rating   budget    -0.176002
# votes    genre     -0.145307
# genre    votes     -0.145307
# score    country   -0.133348
# country  score     -0.133348
# dtype: float64

# %%
high_corr = sorted_pairs[(sorted_pairs)>0.5]

high_corr.head(10)
# Out:
# votes     gross       0.630757
# gross     votes       0.630757
#           budget      0.740395
# budget    gross       0.740395
# released  year        0.992136
# year      released    0.992136
# name      name        1.000000
# director  director    1.000000
# gross     gross       1.000000
# budget    budget      1.000000
# dtype: float64

# %%
# Film budget and votes had the highest positive correlation with gross earnings
